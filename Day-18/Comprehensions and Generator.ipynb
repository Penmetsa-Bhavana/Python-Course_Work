# %% [markdown]
# # COMPREHENSIONS AND GENERATOR
#
# ## LIST COMPREHENSION
#
# - List comprehension is a short and simple way to create a list.
# - It is used to generate a new list from an existing iterable.
# - It can contain an expression, `for` loop, and optional condition.
#
# ### SYNTAX
#
# [expression for item in iterable]
#
# ## LIST COMPREHENSION WITH IF CONDITION
#
# - The `if` condition is used to filter elements.
# - Only elements satisfying the condition are included in the list.
#
# ### SYNTAX
#
# [expression for item in iterable if condition]
#
# ## LIST COMPREHENSION WITH IF-ELSE CONDITION
#
# - `if-else` can be used to choose between two expressions.
# - The `if-else` condition is written before the `for` loop.
#
# ### SYNTAX
#
# [expression_if_true if condition else expression_if_false for item in iterable]
#
# ## LIST COMPREHENSION WITH MATRIX
#
# - List comprehension can be used to create and process matrices.
# - Nested list comprehensions are used to work with rows and columns.
#
# ## DICTIONARY COMPREHENSION
#
# - Dictionary comprehension is a short way to create a dictionary.
# - It creates key-value pairs using an iterable.
#
# ### SYNTAX
#
# {key: value for item in iterable}
#
# ## SET COMPREHENSION
#
# - Set comprehension is used to create a set in a concise way.
# - It automatically removes duplicate values.
#
# ### SYNTAX
#
# {expression for item in iterable}
#
# ## GENERATOR
#
# - A generator is a special type of iterator used to generate values one at a time.
# - Generators are memory efficient because they do not store all values at once.
# - The `yield` keyword is used to produce values from a generator.
# - A generator function returns a generator object.
# - Values are generated only when they are requested.
#
# ### SYNTAX
#
# def generator_function():
#     yield value

# %%
# LIST COMPREHENSION

numbers = [1, 2, 3, 4, 5]

squares = [x * x for x in numbers]

print(squares)
# Out:
# [1, 4, 9, 16, 25]

# %%
# LIST COMPREHENSION WITH IF CONDITION

numbers = [1, 2, 3, 4, 5, 6]

even = [x for x in numbers if x % 2 == 0]

print(even)
# Out:
# [2, 4, 6]

# %%
# LIST COMPREHENSION WITH IF-ELSE CONDITION

numbers = [1, 2, 3, 4, 5]

result = ["Even" if x % 2 == 0 else "Odd" for x in numbers]

print(result)
# Out:
# ['Odd', 'Even', 'Odd', 'Even', 'Odd']

# %%
# LIST COMPREHENSION WITH MATRIX

matrix = [[1, 2], [3, 4], [5, 6]]

result = [[x * 2 for x in row] for row in matrix]

print(result)
# Out:
# [[2, 4], [6, 8], [10, 12]]

# %%
# DICTIONARY COMPREHENSION

numbers = [1, 2, 3, 4, 5]

squares = {x: x * x for x in numbers}

print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
# SET COMPREHENSION

numbers = [1, 2, 2, 3, 4, 4, 5]

squares = {x * x for x in numbers}

print(squares)
# Out:
# {1, 4, 9, 16, 25}

# %%
# GENERATOR

def numbers():
    for i in range(1, 6):
        yield i

result = numbers()

for value in result:
    print(value)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# GENERATOR FOR SQUARES

def squares(n):
    for i in range(1, n + 1):
        yield i * i

for value in squares(5):
    print(value)
# Out:
# 1
# 4
# 9
# 16
# 25
