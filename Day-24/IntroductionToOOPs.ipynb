# %% [markdown]
# # INTRODUCTION TO OOP CONCEPTS
#
# ## WHAT IS OOP?
#
# OOP stands for Object-Oriented Programming.
#
# Object-Oriented Programming is a programming approach based on
# classes and objects. It helps organize programs by combining
# data and functions into a single unit.
#
# ## OOP CONCEPTS
#
# The main concepts of OOP are:
#
# 1. Class
# 2. Object
# 3. Encapsulation
# 4. Inheritance
# 5. Polymorphism
# 6. Abstraction
#
# ## CLASS
#
# A class is a blueprint or template used to create objects.
# It defines the attributes and methods that an object can have.
#
# ## OBJECT
#
# An object is an instance of a class.
# It is used to access the attributes and methods defined in the class.
#
# ## CONSTRUCTOR
#
# A constructor is a special method that is automatically called
# when an object is created.
#
# In Python, the constructor is represented by __init__().
#
# ## SYNTAX FOR CREATING A CLASS
#
# class ClassName:
#     # attributes and methods
#
#
# ## SYNTAX FOR CREATING AN OBJECT
#
# object_name = ClassName()
#
#
# ## SYNTAX FOR CREATING A CONSTRUCTOR
#
# class ClassName:
#
#     def __init__(self):
#         # initialization code

# %%
# Creating a simple class

class Student:
    name = "Bhavana"
    age = 22

print(Student.name)
print(Student.age)
# Out:
# Bhavana
# 22

# %%
# Creating an object

class Student:
    name = "Bhavana"
    age = 22

student1 = Student()

print(student1.name)
print(student1.age)
# Out:
# Bhavana
# 22

# %%
# Class with method

class Student:

    def display(self):
        print("Student details")

student1 = Student()

student1.display()
# Out:
# Student details

# %%
# Class with constructor

class Student:

    def __init__(self, name, age):
        self.name = name
        self.age = age

student1 = Student("Bhavana", 22)

print("Name:", student1.name)
print("Age:", student1.age)
# Out:
# Name: Bhavana
# Age: 22

# %%
# Class, object and constructor

class Employee:

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display(self):
        print("Name:", self.name)
        print("Salary:", self.salary)


employee1 = Employee("Bhavana", 90000)

employee1.display()
# Out:
# Name: Bhavana
# Salary: 90000
