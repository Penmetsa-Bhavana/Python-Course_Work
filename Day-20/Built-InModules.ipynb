# %% [markdown]
# # BUILT-IN MODULES
#
# Built-in modules are modules that are already available in Python.
# They provide useful functions and features for performing common tasks.
#
# ## IMPORTANT BUILT-IN MODULES
#
# ### 1. math
# The math module provides mathematical functions such as square root,
# factorial, power, floor, and ceiling.
#
# ### 2. random
# The random module is used to generate random numbers and select
# random elements from sequences.
#
# ### 3. sys
# The sys module provides functions and variables related to the
# Python interpreter and system environment.
#
# ### 4. platform
# The platform module provides information about the operating system,
# machine, processor, and Python version.
#
# ### 5. collections
# The collections module provides specialized container datatypes
# such as Counter, defaultdict, and deque.
#
# ### 6. itertools
# The itertools module provides functions for creating and working
# with iterators efficiently.
#
# ### 7. datetime
# The datetime module is used to work with dates and times.

# %%
# Math module

import math

num = 25

print("Square root:", math.sqrt(num))
print("Power:", math.pow(2, 3))
print("Factorial:", math.factorial(5))
print("Ceiling:", math.ceil(4.3))
print("Floor:", math.floor(4.8))
# Out:
# Square root: 5.0
# Power: 8.0
# Factorial: 120
# Ceiling: 5
# Floor: 4

# %%
# Random module

import random

numbers = [10, 20, 30, 40, 50]

# randint() - generates a random integer within a range
print("Random integer:", random.randint(1, 100))

# choice() - selects one random element
print("Random choice:", random.choice(numbers))

# choices() - selects multiple random elements
print("Random choices:", random.choices(numbers, k=3))

# sample() - selects multiple unique random elements
print("Random sample:", random.sample(numbers, k=3))

# shuffle() - randomly rearranges the elements
random.shuffle(numbers)
print("Shuffled list:", numbers)
# Out:
# Random integer: 89
# Random choice: 20
# Random choices: [50, 20, 50]
# Random sample: [50, 40, 10]
# Shuffled list: [20, 40, 10, 50, 30]

# %%
# Sys module

import sys

print("Python version:", sys.version)
print("Platform:", sys.platform)
print("Python executable:", sys.executable)

# %%
# Collections module

from collections import Counter

numbers = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

count = Counter(numbers)

print("Frequency of elements:", count)
# Out:
# Frequency of elements: Counter({4: 4, 3: 3, 2: 2, 1: 1})

# %%
# Datetime module

import datetime

current = datetime.datetime.now()

print("Current date and time:", current)
print("Date:", current.date())
print("Time:", current.time())
