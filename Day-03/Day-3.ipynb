# %% [markdown]
# DATATYPES
#
# ->Numeric: integers, floats, complex
# ->Sequence: list, tuple, string
# ->Mapping: dictionary
# ->Boolean: True/False
# ->None Type: None

# %%
#Numeric Datatype
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x=13.45
y=10+4j
print(type(x))
print(type(y))
# Out:
# <class 'float'>
# <class 'complex'>

# %%
#Sequence
l=[1,2,3,4,5]
t=(1,2,3,4,5)
str="Hello World"
print(type(l))
print(type(t))
print(type(str))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'str'>

# %%
#Mapping
d={"name":"John","age":30}
s={1,2,3,4,5}
print(type(d))
print(type(s))
# Out:
# <class 'dict'>
# <class 'set'>

# %%
#Boolean
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
#None Type
b=None
print(type(b))
# Out:
# <class 'NoneType'>

# %% [markdown]
# TYPE CASTING
#
# 1.Implicit- Machine itself does the conversion.
# 2.Explicit- we forcefully convert one type to another.

# %%
#Implicit Type Conversion
x=10
y=9.5
print(x+y)
# Out:
# 19.5

# %%
#Explicit Type Conversion
s1='123'
x=int(s1)
print(x)
# Out:
# 123
