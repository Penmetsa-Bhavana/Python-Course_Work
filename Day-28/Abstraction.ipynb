# %% [markdown]
# # ABSTRACTION
#
# Abstraction is an OOP concept that hides the internal implementation
# details and shows only the necessary information to the user.
#
# It helps reduce complexity and makes programs easier to use and maintain.
#
# ## ABSTRACT CLASS
#
# An abstract class is a class that contains one or more abstract methods.
#
# An abstract class cannot be used to create objects directly.
#
# In Python, abstract classes can be created using the ABC module.
#
# ## ABSTRACT METHOD
#
# An abstract method is a method that is declared in the parent class
# but does not contain its implementation.
#
# The child class must provide the implementation of the abstract method.
#
# ## MODULES USED FOR ABSTRACTION
#
# ### ABC
# ABC stands for Abstract Base Class.
# It is used to create abstract classes.
#
# ### @abstractmethod
# It is a decorator used to declare a method as an abstract method.
#
# ## SYNTAX
#
# from abc import ABC, abstractmethod
#
# class ClassName(ABC):
#
#     @abstractmethod
#     def method_name(self):
#         pass

# %%
# Abstraction using Vehicle

from abc import ABC, abstractmethod


class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass


class Car(Vehicle):

    def start(self):
        print("Car starts with a key")


class Bike(Vehicle):

    def start(self):
        print("Bike starts with a self-start button")


car = Car()
bike = Bike()

car.start()
bike.start()
# Out:
# Car starts with a key
# Bike starts with a self-start button

# %%
# Abstraction using Payment

from abc import ABC, abstractmethod


class Payment(ABC):

    @abstractmethod
    def pay(self, amount):
        pass


class CreditCard(Payment):

    def pay(self, amount):
        print("Paid", amount, "using Credit Card")


class UPI(Payment):

    def pay(self, amount):
        print("Paid", amount, "using UPI")


card = CreditCard()
upi = UPI()

card.pay(1000)
upi.pay(500)
# Out:
# Paid 1000 using Credit Card
# Paid 500 using UPI

# %%
# Abstract class with abstract and normal methods

from abc import ABC, abstractmethod


class Employee(ABC):

    def company(self):
        print("Employee works in a company")

    @abstractmethod
    def work(self):
        pass


class Developer(Employee):

    def work(self):
        print("Developer writes code")


developer = Developer()

developer.company()
developer.work()
# Out:
# Employee works in a company
# Developer writes code
