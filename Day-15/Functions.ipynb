# %% [markdown]
# ## FUNCTIONS
#
# - A function is a block of reusable code that performs a specific task.
# - Functions help to divide a large program into smaller and manageable parts.
# - A function is executed when it is called.
# - Functions improve code reusability, readability, and maintainability.
#
# ## WHY FUNCTIONS?
#
# - Code reusability
# - Reduces code repetition
# - Makes programs easier to understand
# - Makes debugging easier
# - Helps divide a large program into smaller modules
# - Makes code easier to maintain
#
# ## TYPES OF FUNCTIONS
#
# ### 1. BUILT-IN FUNCTIONS
#
# - Functions already provided by Python.
# - Examples: `print()`, `len()`, `max()`, `min()`, `sum()`, `type()`
#
# ### 2. USER-DEFINED FUNCTIONS
#
# - Functions created by the programmer according to the requirement.
# - Defined using the `def` keyword.
#
# ## USER-DEFINED FUNCTION SYNTAX
#
# def function_name(parameters):
#     statements
#     return value
#
# ## TYPES OF USER-DEFINED FUNCTIONS
#
# ### 1. WITHOUT ARGUMENTS AND WITHOUT RETURN VALUE
#
# - Function does not accept any arguments.
# - Function does not return a value.
#
# ### 2. WITH ARGUMENTS AND WITHOUT RETURN VALUE
#
# - Function accepts arguments.
# - Function performs an operation but does not return a value.
#
# ### 3. WITHOUT ARGUMENTS AND WITH RETURN VALUE
#
# - Function does not accept arguments.
# - Function returns a value using `return`.
#
# ### 4. WITH ARGUMENTS AND WITH RETURN VALUE
#
# - Function accepts arguments.
# - Function performs an operation and returns a value.
#
#
# ## TYPES OF ARGUMENTS
#
# Based on how arguments are passed to a function, functions can be classified into five types.
#
# ### 1. POSITIONAL ARGUMENTS
#
# - Arguments are passed according to the position of the parameters.
# - The order of arguments is important.
#
# ### 2. KEYWORD ARGUMENTS
#
# - Arguments are passed using parameter names.
# - The order of arguments is not important.
#
# ### 3. DEFAULT ARGUMENTS
#
# - Parameters are assigned default values.
# - The default value is used when an argument is not provided.
#
# ### 4. VARIABLE-LENGTH ARGUMENTS
#
# - Used when the number of positional arguments is not fixed.
# - Represented using `*args`.
# - Multiple positional arguments can be passed.
#
# ### 5. VARIABLE-LENGTH KEYWORD ARGUMENTS
#
# - Used when the number of keyword arguments is not fixed.
# - Represented using `**kwargs`.
# - Multiple keyword arguments can be passed as key-value pairs.

# %%
# BUILT-IN FUNCTION

numbers = [10, 20, 30, 40, 50]

print("Length:", len(numbers))
print("Maximum:", max(numbers))
print("Minimum:", min(numbers))
print("Sum:", sum(numbers))
# Out:
# Length: 5
# Maximum: 50
# Minimum: 10
# Sum: 150

# %%
# USER-DEFINED FUNCTION - WITHOUT ARGUMENTS AND WITHOUT RETURN VALUE

def greet():
    print("Hello, Welcome to Python")

greet()
# Out:
# Hello, Welcome to Python

# %%
# USER-DEFINED FUNCTION - WITH ARGUMENTS AND WITHOUT RETURN VALUE

def addition(a, b):
    print("Sum =", a + b)

addition(10, 20)
# Out:
# Sum = 30

# %%
# USER-DEFINED FUNCTION - WITHOUT ARGUMENTS AND WITH RETURN VALUE

def get_number():
    return 100

result = get_number()
print("Number =", result)
# Out:
# Number = 100

# %%
# USER-DEFINED FUNCTION - WITH ARGUMENTS AND WITH RETURN VALUE

def multiply(a, b):
    return a * b

result = multiply(5, 4)
print("Result =", result)
# Out:
# Result = 20

# %%
# POSITIONAL ARGUMENTS

def student(name, age):
    print("Name:", name)
    print("Age:", age)

student("Bhavana", 21)
# Out:
# Name: Bhavana
# Age: 21

# %%
# KEYWORD ARGUMENTS

def student(name, age):
    print("Name:", name)
    print("Age:", age)

student(age=21, name="Bhavana")
# Out:
# Name: Bhavana
# Age: 21

# %%
# DEFAULT ARGUMENTS

def employee(name, company="TCS"):
    print("Name:", name)
    print("Company:", company)

employee("Bhavana")
employee("Anu", "Infosys")
# Out:
# Name: Bhavana
# Company: TCS
# Name: Anu
# Company: Infosys

# %%
# VARIABLE-LENGTH ARGUMENTS

def addition(*args):
    print("Arguments:", args)
    print("Sum =", sum(args))

addition(10, 20)
addition(10, 20, 30, 40)
# Out:
# Arguments: (10, 20)
# Sum = 30
# Arguments: (10, 20, 30, 40)
# Sum = 100

# %%
# VARIABLE-LENGTH KEYWORD ARGUMENTS

def student(**kwargs):
    for key, value in kwargs.items():
        print(key, ":", value)

student(name="Bhavana", age=21, course="Python")
# Out:
# name : Bhavana
# age : 21
# course : Python
