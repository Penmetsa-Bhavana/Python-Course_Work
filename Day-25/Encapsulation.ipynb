# %% [markdown]
# # ENCAPSULATION
#
# Encapsulation is an OOP concept that combines data and methods
# within a class and controls access to the data.
#
# It helps protect the data from direct access and modification.
#
# ## ACCESS SPECIFIERS
#
# Python uses naming conventions to control the accessibility of
# class members.
#
# ### 1. Public
# Public members can be accessed from anywhere.
#
# ### 2. Protected
# Protected members are represented using a single underscore (_).
# They can be accessed within the class and its subclasses.
#
# ### 3. Private
# Private members are represented using double underscores (__).
# They cannot be directly accessed from outside the class.
#
# ## ADVANTAGES OF ENCAPSULATION
#
# - Provides data protection.
# - Controls access to data.
# - Improves code organization.
# - Makes the code easier to maintain.

# %%
# Public member

class Student:

    def __init__(self, name, age):
        self.name = name
        self.age = age


student1 = Student("Bhavana", 22)

print(student1.name)
print(student1.age)
# Out:
# Bhavana
# 22

# %%
# Protected member

class Student:

    def __init__(self, name, age):
        self._name = name
        self._age = age


student1 = Student("Bhavana", 22)

print(student1._name)
print(student1._age)
# Out:
# Bhavana
# 22

# %%
# Private member

class Student:

    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    def display(self):
        print("Name:", self.__name)
        print("Age:", self.__age)


student1 = Student("Bhavana", 22)

student1.display()
# Out:
# Name: Bhavana
# Age: 22

# %%
# Private member cannot be directly accessed

class Student:

    def __init__(self, name):
        self.__name = name


student1 = Student("Bhavana")

print(student1.__name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 11
#       7
#       8
#       9 student1 = Student("Bhavana")
#      10
# ---> 11 print(student1.__name)
#
# AttributeError: 'Student' object has no attribute '__name'
