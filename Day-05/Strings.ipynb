# %% [markdown]
# # DAY 5 - STRINGS
#
# ## STRING
# - Sequence of characters
# - Single, double and triple quotes
# - Immutable and ordered
#
# ## INDEXING
# - Positive indexing
# - Negative indexing
#
# ## SLICING
# - start : stop
# - start : stop : step
# - Positive and negative step
# - Reverse string
#
# ## STRING OPERATIONS
# - Concatenation (+)
# - Repetition (*)
# - Comparison
# - Membership (in, not in)
#
# ## STRING METHODS
# - lower()
# - upper()
# - capitalize()
# - title()
# - swapcase()
#
# ## CHECKING METHODS
# - islower()
# - isupper()
# - isalpha()
# - isdigit()
# - isalnum()
# - isspace()
#
# ## OTHER METHODS
# - strip()
# - lstrip()
# - rstrip()
# - replace()
# - split()
# - join()
#
# ## BUILT-IN FUNCTION
# - len()
#
# ## IMMUTABILITY
# - Strings cannot be changed directly
#
# ## SWAPPING
# - Using temporary variable
# - Using arithmetic operators
# - Python multiple assignment
#
# ## BITWISE NOT OPERATOR
# - ~ operator
# - ~n = -(n + 1)

# %%
# Creating strings
s1 = "Python"
s2 = 'Programming'
s3 = """Python Programming"""

print(s1)
print(s2)
print(s3)

# Indexing
print(s1[0])
print(s1[-1])

# Slicing
print(s1[0:4])
print(s1[::2])
print(s1[::-1])
# Out:
# Python
# Programming
# Python Programming
# P
# n
# Pyth
# Pto
# nohtyP

# %%
# String operations
print(s1 + " " + s2)       # Concatenation
print(s1 * 3)              # Repetition

print("Py" in s1)          # Membership
print("Java" not in s1)

print(s1 == "Python")      # Comparison
# Out:
# Python Programming
# PythonPythonPython
# True
# True
# True

# %%
# String methods
text = "pYtHoN pRoGrAmMiNg"

print(text.lower())
print(text.upper())
print(text.capitalize())
print(text.title())
print(text.swapcase())

print("python".islower())
print("PYTHON".isupper())
print("Python".isalpha())
print("123".isdigit())
print("Python123".isalnum())
print("   ".isspace())
# Out:
# python programming
# PYTHON PROGRAMMING
# Python programming
# Python Programming
# PyThOn PrOgRaMmInG
# True
# True
# True
# True
# True
# True

# %%
# strip, replace, split, join and len
text = "   Python Programming   "

print(text.strip())
print(text.lstrip())
print(text.rstrip())

print(text.replace("Python", "Java"))

words = "Python Programming".split()
print(words)

print(" ".join(words))

print(len(text))
# Out:
# Python Programming
# Python Programming
#    Python Programming
#    Java Programming
# ['Python', 'Programming']
# Python Programming
# 24

# %%
# Strings are immutable
s = "Python"

# s[0] = "J"       # TypeError

s = "J" + s[1:]
print(s)

# Swapping
x = 10
y = 20

x, y = y, x

print(x, y)
# Out:
# Jython
# 20 10
