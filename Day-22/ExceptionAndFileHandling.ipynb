# %% [markdown]
# # EXCEPTION HANDLING AND FILE HANDLING
#
# ## EXCEPTION HANDLING
#
# Exception handling is used to handle errors that occur during the
# execution of a Python program without stopping the entire program.
#
# ### WHAT IS AN EXCEPTION?
#
# An exception is an error that occurs during the execution of a program.
# Python provides exception handling mechanisms to detect and handle
# these errors.
#
# ### RUNTIME ERRORS
#
# Runtime errors occur while a program is running.
#
# ### 1. ZeroDivisionError
# Occurs when a number is divided by zero.
#
# ### 2. ValueError
# Occurs when a function receives an inappropriate value.
#
# ### 3. KeyError
# Occurs when we try to access a dictionary key that does not exist.
#
# ### 4. IndexError
# Occurs when we try to access an index that is outside the range
# of a sequence.
#
# ### 5. FileNotFoundError
# Occurs when we try to open a file that does not exist.
#
# ### 6. AttributeError
# Occurs when we try to access an attribute or method that an object
# does not have.
#
# ### EXCEPTION HANDLING USING try AND except
#
# The try block contains code that may produce an exception.
# The except block is used to handle the exception.
#
# ### SYNTAX
#
# try:
#     # Code that may cause an exception
# except:
#     # Code to handle the exception
#
#
# ## FILE HANDLING
#
# File handling is used to create, read, write, and modify files
# using Python.
#
# ### FILE OPERATIONS
#
# ### 1. Open
# The open() function is used to open a file.
#
# ### 2. Read
# The read() function is used to read the contents of a file.
#
# ### 3. Write
# The write() function is used to write data into a file.
#
# ### 4. Close
# The close() function is used to close an opened file.
#
# ### SYNTAX
#
# file = open("filename.txt", "mode")
#
# ### FILE MODES
#
# ### r - Read Mode
# Opens a file for reading. The file must already exist.
#
# ### w - Write Mode
# Opens a file for writing. Creates a new file if it does not exist.
# If the file already exists, its contents are overwritten.
#
# ### a - Append Mode
# Opens a file for adding data at the end.
# Creates a new file if it does not exist.
#
# ### r+ - Read and Write Mode
# Opens a file for both reading and writing.
# The file must already exist.
#
# ### w+ - Write and Read Mode
# Opens a file for both writing and reading.
# Creates a new file if it does not exist and overwrites existing content.
#
# ### a+ - Append and Read Mode
# Opens a file for both appending and reading.
# Creates a new file if it does not exist.

# %%
# ZeroDivisionError

a = 10
b = 0

print(a / b)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 a = 10
#       4 b = 0
#       5
# ----> 6 print(a / b)
#
# ZeroDivisionError: division by zero

# %%
# ValueError

num = int("hello")

print(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 3
#       1 # ValueError
#       2
# ----> 3 num = int("hello")
#       4
#       5 print(num)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
# KeyError

student = {
    "name": "Bhavana",
    "age": 22
}

print(student["marks"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 8
#       4     "name": "Bhavana",
#       5     "age": 22
#       6 }
#       7
# ----> 8 print(student["marks"])
#
# KeyError: 'marks'

# %%
# IndexError

numbers = [10, 20, 30]

print(numbers[5])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 # IndexError
#       2
#       3 numbers = [10, 20, 30]
#       4
# ----> 5 print(numbers[5])
#
# IndexError: list index out of range

# %%
# FileNotFoundError

file = open("abc.txt", "r")

print(file.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 # FileNotFoundError
#       2
# ----> 3 file = open("abc.txt", "r")
#       4
#       5 print(file.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'abc.txt'

# %%
# AttributeError

numbers = [10, 20, 30]

numbers.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       1 # AttributeError
#       2
#       3 numbers = [10, 20, 30]
#       4
# ----> 5 numbers.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))

    print("Result:", num1 / num2)

except ZeroDivisionError:
    print("Cannot divide by zero.")

except ValueError:
    print("Please enter valid numbers.")
# Out:
# Cannot divide by zero.

# %%
# Write and read a file

file = open("sample.txt", "w")

file.write("Welcome to Python File Handling.")

file.close()

file = open("sample.txt", "r")

data = file.read()

print(data)

file.close()
# Out:
# Welcome to Python File Handling.

# %%
# Append data to a file

file = open("sample.txt", "a")

file.write("\nThis is an additional line.")

file.close()

file = open("sample.txt", "r")

print(file.read())

file.close()
# Out:
# Welcome to Python File Handling.
# This is an additional line.
