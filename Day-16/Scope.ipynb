# %% [markdown]
# ## SCOPE
#
# - Scope refers to the region of a program where a variable or name can be accessed.
# - The scope of a variable determines where it can be used.
# - In Python, variables can have different scopes depending on where they are created.
#
# ## TYPES OF SCOPE
#
# ### 1. LOCAL SCOPE
#
# - A variable created inside a function has local scope.
# - It can be accessed only within that function.
# - It cannot be directly accessed outside the function.
#
# ### 2. GLOBAL SCOPE
#
# - A variable created outside all functions has global scope.
# - It can be accessed throughout the program.
# - A global variable can be accessed inside functions.
#
# ### 3. ENCLOSING SCOPE
#
# - Occurs when a function is defined inside another function.
# - A variable in the outer function has enclosing scope for the inner function.
# - The inner function can access variables of the outer function.
#
# ### 4. BUILT-IN SCOPE
#
# - Contains names already provided by Python.
# - These names can be used anywhere in the program.
# - Examples: `print()`, `len()`, `sum()`, `type()`, `range()`
#
# ## LEGB RULE
#
# Python searches for a variable in the following order:
#
# - **L - Local:** Inside the current function
# - **E - Enclosing:** Inside the enclosing/outer function
# - **G - Global:** At the program level
# - **B - Built-in:** Names provided by Python
#
# ## GLOBAL KEYWORD
#
# - The `global` keyword is used to modify a global variable inside a function.
# - Without the `global` keyword, assigning a value to a variable inside a function creates a local variable.
#
# ## NONLOCAL KEYWORD
#
# - The `nonlocal` keyword is used inside a nested function.
# - It allows the inner function to modify a variable belonging to the enclosing function.

# %%
# LOCAL SCOPE

def display():
    name = "Bhavana"
    print(name)

display()
# Out:
# Bhavana

# %%
# GLOBAL SCOPE

name = "Bhavana"

def display():
    print(name)

display()
print(name)
# Out:
# Bhavana
# Bhavana

# %%
# LOCAL AND GLOBAL SCOPE

name = "Bhavana"

def display():
    name = "Anu"
    print("Local:", name)

display()
print("Global:", name)
# Out:
# Local: Anu
# Global: Bhavana

# %%
# ENCLOSING SCOPE

def outer():
    name = "Bhavana"

    def inner():
        print(name)

    inner()

outer()
# Out:
# Bhavana

# %%
# BUILT-IN SCOPE

numbers = [10, 20, 30, 40]

print(len(numbers))
print(max(numbers))
print(sum(numbers))
# Out:
# 4
# 40
# 100

# %%
# GLOBAL KEYWORD

count = 10

def update():
    global count
    count = 20

update()
print(count)
# Out:
# 20

# %%
# NONLOCAL KEYWORD

def outer():
    count = 10

    def inner():
        nonlocal count
        count = 20

    inner()
    print(count)

outer()
# Out:
# 20

# %%
# PROGRAM TO UNDERSTAND LOCAL AND GLOBAL VARIABLES

x = 100

def test():
    x = 50
    print("Inside function:", x)

test()
print("Outside function:", x)
# Out:
# Inside function: 50
# Outside function: 100

# %%
# PROGRAM TO MODIFY A GLOBAL VARIABLE

marks = 50

def update_marks():
    global marks
    marks = 90

update_marks()
print("Marks:", marks)
# Out:
# Marks: 90
