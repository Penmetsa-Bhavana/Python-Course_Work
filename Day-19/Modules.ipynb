# %% [markdown]
# ## MODULES
#
# - A module is a Python file containing functions, classes, variables, and statements.
# - A module is saved with the `.py` extension.
# - Modules help to organize Python programs into separate files.
# - Python provides many built-in modules, and we can also create our own modules.
#
# ## WHY MODULES?
#
# - Code reusability
# - Reduces code duplication
# - Organizes large programs
# - Makes code easier to maintain
# - Provides ready-to-use functions and classes
# - Helps divide a large program into smaller files
#
# ## TYPES OF MODULES
#
# ### 1. BUILT-IN MODULES
#
# - Modules provided by Python.
# - Examples: `math`, `random`, `datetime`, `os`
#
# ### 2. USER-DEFINED MODULES
#
# - Modules created by the programmer.
# - Any Python file can be used as a module.
#
# ### 3. THIRD-PARTY MODULES
#
# - Modules developed by external developers or organizations.
# - They are usually installed using `pip`.
# - Examples: `numpy`, `pandas`, `requests`
#
# ## DIFFERENT WAYS OF IMPORTING MODULES
#
# ### 1. IMPORT ENTIRE MODULE
#
# import module_name
#
# ### 2. IMPORT WITH ALIAS
#
# import module_name as alias
#
# ### 3. IMPORT SPECIFIC FUNCTION
#
# from module_name import function_name
#
# ### 4. IMPORT MULTIPLE FUNCTIONS
#
# from module_name import function1, function2
#
# ### 5. IMPORT ALL
#
# from module_name import *
#
# ## USING FUNCTIONS FROM A MODULE
#
# - When an entire module is imported, the module name is used with the dot operator.
# - Example: `math.sqrt(25)`
#
# ## SIMPLE CALCULATOR USING MODULES
#
# - A calculator can be created by defining arithmetic operations in a separate Python file.
# - The calculator module can then be imported into another Python program.
# - This demonstrates code reusability and user-defined modules.

# %%
# BUILT-IN MODULE

import math

print("Square root:", math.sqrt(25))
print("Power:", math.pow(2, 3))
print("Factorial:", math.factorial(5))
# Out:
# Square root: 5.0
# Power: 8.0
# Factorial: 120

# %%
# IMPORT MODULE WITH ALIAS

import math as m

print("Square root:", m.sqrt(36))
print("Value of pi:", m.pi)
# Out:
# Square root: 6.0
# Value of pi: 3.141592653589793

# %%
# IMPORT SPECIFIC FUNCTION

from math import sqrt

print("Square root:", sqrt(49))
# Out:
# Square root: 7.0

# %%
# IMPORT MULTIPLE FUNCTIONS

from math import sqrt, factorial

print("Square root:", sqrt(64))
print("Factorial:", factorial(5))
# Out:
# Square root: 8.0
# Factorial: 120
