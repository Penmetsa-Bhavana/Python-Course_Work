# %% [markdown]
# # RECURSION, LAMBDA FUNCTIONS AND HIGHER ORDER FUNCTIONS
#
# ## RECURSION
#
# - Recursion is a process in which a function calls itself.
# - A recursive function solves a problem by breaking it into smaller versions of the same problem.
# - Every recursive function must have a **base condition** to stop the recursion.
#
# ## SYNTAX
#
# def function(parameters):
#     if base_condition:
#         return value
#     else:
#         return function(modified_parameters)
#
# ## POINTS TO REMEMBER WHILE USING RECURSION
#
# - A base condition is compulsory.
# - The recursive call should move towards the base condition.
# - Without a proper base condition, infinite recursion may occur.
# - Each recursive call creates a new function call.
# - Recursion can be used as an alternative to loops for certain problems.
# - Excessive recursion can consume more memory.
#
# ## TYPES OF RECURSIVE FUNCTIONS
#
# ### 1. DIRECT RECURSION
#
# - A function directly calls itself.
# - Example: `function()` calls `function()`.
#
# ### 2. INDIRECT RECURSION
#
# - Two or more functions call each other.
# - Example: `function1()` calls `function2()` and `function2()` calls `function1()`.
#
# ## LAMBDA FUNCTIONS
#
# - A lambda function is a small anonymous function.
# - It is created using the `lambda` keyword.
# - It can take any number of arguments but contains only one expression.
# - Lambda functions are generally used for short and simple operations.
#
# ## SYNTAX
#
# lambda arguments: expression
#
# ## ANONYMOUS FUNCTION
#
# - A lambda function is called an anonymous function because it does not require a function name using `def`.
# - It can be assigned to a variable or directly passed to another function.
#
# ## HIGHER ORDER FUNCTIONS
#
# - A higher order function is a function that accepts another function as an argument or returns a function as its result.
# - Higher order functions are commonly used with lambda functions.
# - Examples: `map()`, `filter()`, `reduce()`, and `sorted()` with a key function.

# %%
# DIRECT RECURSION

def countdown(n):
    if n == 0:
        return
    print(n)
    countdown(n - 1)

countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
# FACTORIAL USING RECURSION

def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

print("Factorial:", factorial(5))
# Out:
# Factorial: 120

# %%
# SUM OF NUMBERS USING RECURSION

def sum_numbers(n):
    if n == 0:
        return 0
    return n + sum_numbers(n - 1)

print("Sum:", sum_numbers(5))
# Out:
# Sum: 15

# %%
# FIBONACCI SERIES USING RECURSION

def fibonacci(n):
    if n <= 1:
        return n
    return fibonacci(n - 1) + fibonacci(n - 2)

for i in range(7):
    print(fibonacci(i), end=" ")
# Out:
# 0 1 1 2 3 5 8

# %%
# INDIRECT RECURSION

def function1(n):
    if n > 0:
        print(n)
        function2(n - 1)

def function2(n):
    if n > 0:
        print(n)
        function1(n - 1)

function1(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
# LAMBDA FUNCTION

square = lambda x: x * x

print(square(5))
# Out:
# 25

# %%
# LAMBDA FUNCTION WITH MULTIPLE ARGUMENTS

addition = lambda a, b: a + b

print(addition(10, 20))
# Out:
# 30

# %%
# HIGHER ORDER FUNCTION - FUNCTION AS AN ARGUMENT

def calculate(operation, a, b):
    return operation(a, b)

addition = lambda x, y: x + y

print(calculate(addition, 10, 20))
# Out:
# 30

# %%
# MAP() - HIGHER ORDER FUNCTION

numbers = [1, 2, 3, 4, 5]

result = list(map(lambda x: x * 2, numbers))

print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
# FILTER() - HIGHER ORDER FUNCTION

numbers = [1, 2, 3, 4, 5, 6]

result = list(filter(lambda x: x % 2 == 0, numbers))

print(result)
# Out:
# [2, 4, 6]

# %%
# REDUCE() - HIGHER ORDER FUNCTION

from functools import reduce

numbers = [1, 2, 3, 4, 5]

result = reduce(lambda x, y: x + y, numbers)

print(result)
# Out:
# 15
